# %% [markdown]
# ## Pandas
# is the most popular Python library for data analysis, help dealing with data set and it will extract the data from that CSV into a DataFrame.
#
# <img src='../data/pandas.png'>
#
# ### IMPORT OF Pandas :-
# - import `pandas` as `pd`

# %%
import pandas as pd

# %% [markdown]
# #### Series & DataFrame
#
# ##### 1. Series:
#  is considered column in an excel sheet.
# ##### 2. DataFrame:
#  is a table, datasets arrange in rows and columns,
# ###### If a DataFrame is a table, a Series is a list.
#
# <img src='../data/series-and-dataframe.width-1200.png'>

# %% [markdown]
# #### Create series
# - created by loading the datasets from existing storage like CSV file, and Excel file.
# - can be created from the lists, dictionary, and from a scalar value etc.

# %%
pd.Series([3,2,0,1])
# Out:
# 0    3
# 1    2
# 2    0
# 3    1
# dtype: int64

# %%
#set index and name
pd.Series([3,2,0,1], index=['Day_1', 'Day_2','Day_3','Day_4'], name='Appels')
# Out:
# Day_1    3
# Day_2    2
# Day_3    0
# Day_4    1
# Name: Appels, dtype: int64

# %% [markdown]
# #### Create DataFrame
# - can be created is an Empty Dataframe by calling a dataframe constructor.
# - can be created from dict narray / lists ,Lists and List of Dicts.

# %%
# create dict
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}

# keys are the column names 
# values are a list of entries
#then pass it to the pandas DataFrame constructor
mydata_frame= pd.DataFrame(data)
mydata_frame
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
# set index ( row labels)
import pandas as pd
mydata_frame= pd.DataFrame(data,index=['Day_1', 'Day_2','Day_3','Day_4'])
mydata_frame
# Out:
#        apples  oranges
# Day_1       3        0
# Day_2       2        3
# Day_3       0        7
# Day_4       1        2

# %% [markdown]
# ###### Q: create a DataFrame by passing a list of dictionaries and the row indices.

# %% [markdown]
# ### Reading data files
# most of the time, we won't actually be creating our own data by hand. Instead, we'll be working with data that already exists.
# Data can be stored in different forms and formats. as(txt,csv,Excel...)
#
# - we can read data.csv (Comma-Separated Values) into a DataFrame by `pd.read_csv()`

# %%
'''
INTRO: DATA SET
Medium is one of the most famous tools for spreading knowledge about almost any field. 
It is widely used to published articles on ML, AI, and data science. 
This dataset is the collection of about 337 articles in such fields

'''
import pandas as pd
# change path your data
data_f=pd.read_csv(r'..\data\articles.csv')
data_f
# Out:
#                   author claps  reading_time  \
# 0             Justin Lee  8.3K            11
# 1            Conor Dewey  1.4K             7
# 2       William Koehrsen  2.8K            11
# 3           Gant Laborde  1.3K             7
# 4       Emmanuel Ameisen   935            11
# ..                   ...   ...           ...
# 332       Daniel Simmons  3.4K             8
# 333  Eugenio Culurciello  2.8K            13
# 334           Devin Soni  5.8K             4
# 335      Carlos E. Perez  3.9K             7
# 336      Nityesh Agarwal  2.4K            13
#
#                                                   link  \
# 0    https://medium.com/swlh/chatbots-were-the-next...
# 1    https://towardsdatascience.com/python-for-data...
# 2    https://towardsdatascience.com/automated-featu...
# 3    https://medium.freecodecamp.org/machine-learni...
# 4    https://blog.insightdatascience.com/reinforcem...
# ..                                                 ...
# 332  https://itnext.io/you-can-build-a-neural-netwo...
# 333  https://towardsdatascience.com/artificial-inte...
# 334  https://towardsdatascience.com/spiking-neural-...
# 335  https://medium.com/intuitionmachine/neurons-ar...
# 336  https://towardsdatascience.com/wth-does-a-neur...
#
#                                                  title  \
# 0    Chatbots were the next big thing: what happene...
# 1    Python for Data Science: 8 Concepts You May Ha...
# 2    Automated Feature Engineering in Python – Towa...
# 3    Machine Learning: how to go from Zero to Hero ...
# 4    Reinforcement Learning from scratch – Insight ...
# ..                                                 ...
# 332  You can build a neural network in JavaScript e...
# 333  Artificial Intelligence, AI in 2018 and beyond...
# 334  Spiking Neural Networks, the Next Generation o...
# 335  Surprise! Neurons are Now More Complex than We...
# 336  “WTH does a neural network even learn??” — a n...
#
#                                                   text
# 0    Oh, how the headlines blared:\nChatbots were T...
# 1    If you’ve ever found yourself looking up the s...
# 2    Machine learning is increasingly moving from h...
# 3    If your understanding of A.I. and Machine Lear...
# 4    Want to learn about applied Artificial Intelli...
# ..                                                 ...
# 332  Click here to share this article on LinkedIn »...
# 333  These are my opinions on where deep neural net...
# 334  Everyone who has been remotely tuned in to rec...
# 335  One of the biggest misconceptions around is th...
# 336  I believe, we all have that psychologist/philo...
#
# [337 rows x 6 columns]

# %% [markdown]
#  We can examine the contents of DataFrame using the ` head() ` command , which display the first five rows by default

# %%
data_f.head(5)
# Out:
#              author claps  reading_time  \
# 0        Justin Lee  8.3K            11
# 1       Conor Dewey  1.4K             7
# 2  William Koehrsen  2.8K            11
# 3      Gant Laborde  1.3K             7
# 4  Emmanuel Ameisen   935            11
#
#                                                 link  \
# 0  https://medium.com/swlh/chatbots-were-the-next...
# 1  https://towardsdatascience.com/python-for-data...
# 2  https://towardsdatascience.com/automated-featu...
# 3  https://medium.freecodecamp.org/machine-learni...
# 4  https://blog.insightdatascience.com/reinforcem...
#
#                                                title  \
# 0  Chatbots were the next big thing: what happene...
# 1  Python for Data Science: 8 Concepts You May Ha...
# 2  Automated Feature Engineering in Python – Towa...
# 3  Machine Learning: how to go from Zero to Hero ...
# 4  Reinforcement Learning from scratch – Insight ...
#
#                                                 text
# 0  Oh, how the headlines blared:\nChatbots were T...
# 1  If you’ve ever found yourself looking up the s...
# 2  Machine learning is increasingly moving from h...
# 3  If your understanding of A.I. and Machine Lear...
# 4  Want to learn about applied Artificial Intelli...

# %% [markdown]
# we can use ` tail() `To see the last five rows

# %%
data_f.tail()
# Out:
#                   author claps  reading_time  \
# 332       Daniel Simmons  3.4K             8
# 333  Eugenio Culurciello  2.8K            13
# 334           Devin Soni  5.8K             4
# 335      Carlos E. Perez  3.9K             7
# 336      Nityesh Agarwal  2.4K            13
#
#                                                   link  \
# 332  https://itnext.io/you-can-build-a-neural-netwo...
# 333  https://towardsdatascience.com/artificial-inte...
# 334  https://towardsdatascience.com/spiking-neural-...
# 335  https://medium.com/intuitionmachine/neurons-ar...
# 336  https://towardsdatascience.com/wth-does-a-neur...
#
#                                                  title  \
# 332  You can build a neural network in JavaScript e...
# 333  Artificial Intelligence, AI in 2018 and beyond...
# 334  Spiking Neural Networks, the Next Generation o...
# 335  Surprise! Neurons are Now More Complex than We...
# 336  “WTH does a neural network even learn??” — a n...
#
#                                                   text
# 332  Click here to share this article on LinkedIn »...
# 333  These are my opinions on where deep neural net...
# 334  Everyone who has been remotely tuned in to rec...
# 335  One of the biggest misconceptions around is th...
# 336  I believe, we all have that psychologist/philo...

# %%
#remove index
import pandas as pd
data_f=pd.read_csv('../data/articles.csv', index_col=0) # set index by columns (using name or index)
# we can use set_index()
#data_f.set_index('title')
data_f.head()
# Out:
#                  claps  reading_time  \
# author
# Justin Lee        8.3K            11
# Conor Dewey       1.4K             7
# William Koehrsen  2.8K            11
# Gant Laborde      1.3K             7
# Emmanuel Ameisen   935            11
#
#                                                                link  \
# author
# Justin Lee        https://medium.com/swlh/chatbots-were-the-next...
# Conor Dewey       https://towardsdatascience.com/python-for-data...
# William Koehrsen  https://towardsdatascience.com/automated-featu...
# Gant Laborde      https://medium.freecodecamp.org/machine-learni...
# Emmanuel Ameisen  https://blog.insightdatascience.com/reinforcem...
#
#                                                               title  \
# author
# Justin Lee        Chatbots were the next big thing: what happene...
# Conor Dewey       Python for Data Science: 8 Concepts You May Ha...
# William Koehrsen  Automated Feature Engineering in Python – Towa...
# Gant Laborde      Machine Learning: how to go from Zero to Hero ...
# Emmanuel Ameisen  Reinforcement Learning from scratch – Insight ...
#
#                                                                text
# author
# Justin Lee        Oh, how the headlines blared:\nChatbots were T...
# Conor Dewey       If you’ve ever found yourself looking up the s...
# William Koehrsen  Machine learning is increasingly moving from h...
# Gant Laborde      If your understanding of A.I. and Machine Lear...
# Emmanuel Ameisen  Want to learn about applied Artificial Intelli...

# %%
data_f=pd.read_csv('../data/articles.csv')

# %% [markdown]
# ###### Understanding Our Data
#
# - info() :
#
# method display information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage.

# %%
#info() function is used to get summary of the dataframe
data_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337 entries, 0 to 336
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   author        337 non-null    object
#  1   claps         337 non-null    object
#  2   reading_time  337 non-null    int64
#  3   link          337 non-null    object
#  4   title         337 non-null    object
#  5   text          337 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 15.9+ KB

# %%
data_f=pd.read_csv('../data/articles.csv')
# using describe() "summary function"
data_f.describe()
# Out:
#        reading_time
# count    337.000000
# mean       9.700297
# std        5.482855
# min        2.000000
# 25%        6.000000
# 50%        8.000000
# 75%       13.000000
# max       31.000000

# %%
data_f.reading_time.describe()
# Out:
# count    337.000000
# mean       9.700297
# std        5.482855
# min        2.000000
# 25%        6.000000
# 50%        8.000000
# 75%       13.000000
# max       31.000000
# Name: reading_time, dtype: float64

# %%
data_f.author.describe()
# Out:
# count              337
# unique             182
# top       Adam Geitgey
# freq                16
# Name: author, dtype: object

# %% [markdown]
# <img src='data/Untitled.png'>

# %%
# To see a list of unique values we can use the unique() function
data_f.author.unique()
# note : Although repeated 'Justin Lee' 5 times , There are in unique array
# Each repeated value appears once in unique array
# Out:
# array(['Justin Lee', 'Conor Dewey', 'William Koehrsen', 'Gant Laborde',
#        'Emmanuel Ameisen', 'Irhum Shafkat', 'Sam Drozdov',
#        'Abhishek Parbhakar', 'Aman Dalmia', 'Sophia Arakelyan',
#        'Dr. GP Pulipaka', 'Scott Santens', 'Adam Geitgey', 'Xiaohan Zeng',
#        'Gil Fewster', 'David Venturi', 'Michael Jordan', 'Eran Kampf',
#        'Oliver Lindberg', 'Xu Wenhao', 'Netflix Technology Blog',
#        'Wolf Garbe', 'Paul Christiano', 'Robbie Tilton',
#        'James Faghmous ', 'Datafiniti', 'Arjan Haring 🔮🔨', 'Eventbrite',
#        'Akash Shende', 'Hrishikesh Huilgolkar', 'Shivon Zilis',
#        'AirbnbEng', 'Yingjie Miao ', 'Pinterest Engineering',
#        'Nikhil Dandekar', 'Jeff Smith', 'Chris Jagers', 'John Wittenauer',
#        'Christopher Nguyen', 'Per Harald Borgen', 'Ahmed El Deeb',
#        'Matt Fogel', 'Illia Polosukhin', 'Christophe Bourguignat',
#        "I'Boss Potiwarakorn", 'samim', 'Arthur Juliani', 'Tal Perry',
#        'Andrej Karpathy', 'Vishal Maini', 'Tim Anglade', 'Sophia Ciocca',
#        'Dhruv Parthasarathy', 'Sebastian Heinz', 'Blaise Aguera y Arcas',
#        'James Le', 'Mybridge', 'David Foster', 'George Seif',
#        'Simon Greenman', 'Eugenio Culurciello', 'WiseWolf Fund',
#        'Michael Solana', 'Lance Ulanoff', 'Matt Schlicht',
#        'Milo Spencer-Harper', 'Greg Fish', 'Frank Diana', 'Wildcat2030',
#        'Theo', 'x.ai', 'Roland Trimmel', 'Espen Waldal', 'Joe Johnston',
#        'Nadav Gur', 'Pandorabots', 'Denny Vrandečić', 'Thaddeus Howze',
#        'Tommy Thompson', 'Arik Sosman', 'Tony Aubé', "Matt O'Leary",
#        'Tanay Jaipuria', 'Ben Brown', 'Rand Hindi', 'Chris Dixon',
#        'François Chollet', 'Max Pechyonkin', 'Slav Ivanov',
#        'Geoff Nesnow', 'Aman Agarwal', 'Gaurav Kaila', 'James Loy',
#        'Chintan Trivedi', 'Leon Zhou', 'Erick Muzart Fonseca dos Santos',
#        'Chris Kalahiki', 'Stefan Kojouharov', 'Francesco Gadaleta',
#        'Jim Fleming', 'Christian Hernandez', 'Venture Scanner',
#        'Derrick Harris', 'Kyle McDonald', 'Nathan Benaich',
#        'Erik Hallström', 'Alexandr Honchar', 'Arvind N', 'Gary Marcus',
#        'Bargava', 'Seth Weidman', 'Gabriel Aldamiz...', 'Sarthak Jain',
#        'Emil Wallner', 'James JD Sutton', 'Kai Stinchcombe',
#        'savedroid ICO', 'Brandon Morelli', 'Gabriel Jiménez',
#        'Tyler Elliot Bettilyon', 'Berit Anderson', 'Sirui Li',
#        'Diana Filippova', 'Peter Sweeney', 'E.C. McCarthy',
#        'Jorge Camacho', 'Matt Wiese', "Tim O'Reilly", 'James Cooper',
#        'Joel Leeman', 'Scott Smith', 'iDanScott', 'Josh', 'paulson',
#        'Christopher Wolf Nordlinger', 'Louis Rosenfeld', 'Matt Harvey',
#        'Vivek Yadav', 'Carlos Beltran', 'Oxford University',
#        'Maciej Lipiec', 'Camron Godbout', 'Dominik Felix', 'Greg Gascon',
#        'Keval Patel', 'Eduard Tyantov', 'Maruti Techlabs', 'Jerry Chen',
#        'Gaurav Oberoi', 'Nick Bourdakos', 'Mark Johnson',
#        'Leigh Alexander', 'Daniel Simmons', 'Logan Spears', 'Bharath Raj',
#        'Daniel Rothmann', 'Amine Aoullay', 'Jonathan Balaban',
#        'SAGAR SHARMA', 'Jae Duk Seo', 'Wallarm', 'Maryna Hlaiboroda',
#        'Kelvin Li', 'Avinash Sharma V', "Elle O'Brien", 'Karl N.',
#        'Nikolai Savas', 'Dr Ben Medlock', 'Nieves Ábalos', 'Rohan Kapur',
#        'Shi Yan', 'Ross Goodwin', 'Eric Elliott', 'Waleed Abdulla', 'gk_',
#        'nafrondel', 'Neelabh Pant', 'Favio Vázquez',
#        'Oleksandr Savsunenko', 'Devin Soni', 'Carlos E. Perez',
#        'Nityesh Agarwal'], dtype=object)

# %%
#To see a list of unique values and how often they occur in the dataset
data_f.author.value_counts()
# Out:
# Adam Geitgey           16
# Slav Ivanov            10
# Arthur Juliani         10
# Milo Spencer-Harper     8
# Dhruv Parthasarathy     6
#                        ..
# Rand Hindi              1
# Ben Brown               1
# Tanay Jaipuria          1
# Tony Aubé              1
# Nityesh Agarwal         1
# Name: author, Length: 182, dtype: int64

# %%
data_f.shape
# Out:
# (337, 6)

# %% [markdown]
# ###### Q:Display a summary of the basic information about  data ('medium_data.csv')

# %%
myDataFrame=pd.read_csv('../data/medium_data.csv')
myDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6508 entries, 0 to 6507
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            6508 non-null   int64
#  1   url           6508 non-null   object
#  2   title         6508 non-null   object
#  3   subtitle      3479 non-null   object
#  4   image         6361 non-null   object
#  5   claps         6508 non-null   int64
#  6   responses     6508 non-null   object
#  7   reading_time  6508 non-null   int64
#  8   publication   6508 non-null   object
#  9   date          6508 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 508.6+ KB

# %% [markdown]
# # Accessing Data
# Selecting specific values of a pandas DataFrame or Series to work on is in any data operation you'll run

# %%
import pandas as pd
data_f=pd.read_csv('../data/articles.csv')
data_f
# Out:
#                   author claps  reading_time  \
# 0             Justin Lee  8.3K            11
# 1            Conor Dewey  1.4K             7
# 2       William Koehrsen  2.8K            11
# 3           Gant Laborde  1.3K             7
# 4       Emmanuel Ameisen   935            11
# ..                   ...   ...           ...
# 332       Daniel Simmons  3.4K             8
# 333  Eugenio Culurciello  2.8K            13
# 334           Devin Soni  5.8K             4
# 335      Carlos E. Perez  3.9K             7
# 336      Nityesh Agarwal  2.4K            13
#
#                                                   link  \
# 0    https://medium.com/swlh/chatbots-were-the-next...
# 1    https://towardsdatascience.com/python-for-data...
# 2    https://towardsdatascience.com/automated-featu...
# 3    https://medium.freecodecamp.org/machine-learni...
# 4    https://blog.insightdatascience.com/reinforcem...
# ..                                                 ...
# 332  https://itnext.io/you-can-build-a-neural-netwo...
# 333  https://towardsdatascience.com/artificial-inte...
# 334  https://towardsdatascience.com/spiking-neural-...
# 335  https://medium.com/intuitionmachine/neurons-ar...
# 336  https://towardsdatascience.com/wth-does-a-neur...
#
#                                                  title  \
# 0    Chatbots were the next big thing: what happene...
# 1    Python for Data Science: 8 Concepts You May Ha...
# 2    Automated Feature Engineering in Python – Towa...
# 3    Machine Learning: how to go from Zero to Hero ...
# 4    Reinforcement Learning from scratch – Insight ...
# ..                                                 ...
# 332  You can build a neural network in JavaScript e...
# 333  Artificial Intelligence, AI in 2018 and beyond...
# 334  Spiking Neural Networks, the Next Generation o...
# 335  Surprise! Neurons are Now More Complex than We...
# 336  “WTH does a neural network even learn??” — a n...
#
#                                                   text
# 0    Oh, how the headlines blared:\nChatbots were T...
# 1    If you’ve ever found yourself looking up the s...
# 2    Machine learning is increasingly moving from h...
# 3    If your understanding of A.I. and Machine Lear...
# 4    Want to learn about applied Artificial Intelli...
# ..                                                 ...
# 332  Click here to share this article on LinkedIn »...
# 333  These are my opinions on where deep neural net...
# 334  Everyone who has been remotely tuned in to rec...
# 335  One of the biggest misconceptions around is th...
# 336  I believe, we all have that psychologist/philo...
#
# [337 rows x 6 columns]

# %% [markdown]
# ###### 1.methode (Columns is attribute of object)
# In Python, we can access the property of an object by accessing it as an attribute, Columns in a pandas DataFrame work in much the same way.

# %%
data_f.reading_time
# Out:
# 0      11
# 1       7
# 2      11
# 3       7
# 4      11
#        ..
# 332     8
# 333    13
# 334     4
# 335     7
# 336    13
# Name: reading_time, Length: 337, dtype: int64

# %% [markdown]
# ###### 2. methode (dataframe is dictionary)
# in Python dictionary, we can access its values using the indexing ([]) operator.
#
# - Note:
# the indexing operator [] does have the advantage that it can handle column names with reserved characters in them (e.g. if we had a `Publishing house` column, `dataframe.Publishing house` wouldn't work).

# %%
data_f[['claps','link']]
# Out:
#     claps                                               link
# 0    8.3K  https://medium.com/swlh/chatbots-were-the-next...
# 1    1.4K  https://towardsdatascience.com/python-for-data...
# 2    2.8K  https://towardsdatascience.com/automated-featu...
# 3    1.3K  https://medium.freecodecamp.org/machine-learni...
# 4     935  https://blog.insightdatascience.com/reinforcem...
# ..    ...                                                ...
# 332  3.4K  https://itnext.io/you-can-build-a-neural-netwo...
# 333  2.8K  https://towardsdatascience.com/artificial-inte...
# 334  5.8K  https://towardsdatascience.com/spiking-neural-...
# 335  3.9K  https://medium.com/intuitionmachine/neurons-ar...
# 336  2.4K  https://towardsdatascience.com/wth-does-a-neur...
#
# [337 rows x 2 columns]

# %% [markdown]
# ###### Access entry

# %%
data_f['claps'][3]
# Out:
# '1.3K'

# %% [markdown]
# ###### Accessor operators `loc`  and `iloc`
#
# - `iloc` we treat the dataset like a big matrix (a list of lists) , select data based on its numerical position in the data, this is called 'Index-based selection'.
#
# - `loc` uses the information in the indices and ignores the dataset's indices, this is called ' label-based selection'.

# %%
data_f.head(2)
# Out:
#         author claps  reading_time  \
# 0   Justin Lee  8.3K            11
# 1  Conor Dewey  1.4K             7
#
#                                                 link  \
# 0  https://medium.com/swlh/chatbots-were-the-next...
# 1  https://towardsdatascience.com/python-for-data...
#
#                                                title  \
# 0  Chatbots were the next big thing: what happene...
# 1  Python for Data Science: 8 Concepts You May Ha...
#
#                                                 text
# 0  Oh, how the headlines blared:\nChatbots were T...
# 1  If you’ve ever found yourself looking up the s...

# %%
data_f.iloc[0]
# Out:
# author                                                 Justin Lee
# claps                                                        8.3K
# reading_time                                                   11
# link            https://medium.com/swlh/chatbots-were-the-next...
# title           Chatbots were the next big thing: what happene...
# text            Oh, how the headlines blared:\nChatbots were T...
# Name: 0, dtype: object

# %%
data_f.head(2)
# Out:
#         author claps  reading_time  \
# 0   Justin Lee  8.3K            11
# 1  Conor Dewey  1.4K             7
#
#                                                 link  \
# 0  https://medium.com/swlh/chatbots-were-the-next...
# 1  https://towardsdatascience.com/python-for-data...
#
#                                                title  \
# 0  Chatbots were the next big thing: what happene...
# 1  Python for Data Science: 8 Concepts You May Ha...
#
#                                                 text
# 0  Oh, how the headlines blared:\nChatbots were T...
# 1  If you’ve ever found yourself looking up the s...

# %%
data_f.iloc[:2]
# Out:
#         author claps  reading_time  \
# 0   Justin Lee  8.3K            11
# 1  Conor Dewey  1.4K             7
#
#                                                 link  \
# 0  https://medium.com/swlh/chatbots-were-the-next...
# 1  https://towardsdatascience.com/python-for-data...
#
#                                                title  \
# 0  Chatbots were the next big thing: what happene...
# 1  Python for Data Science: 8 Concepts You May Ha...
#
#                                                 text
# 0  Oh, how the headlines blared:\nChatbots were T...
# 1  If you’ve ever found yourself looking up the s...

# %%
data_f.loc[:5]
# Out:
#              author claps  reading_time  \
# 0        Justin Lee  8.3K            11
# 1       Conor Dewey  1.4K             7
# 2  William Koehrsen  2.8K            11
# 3      Gant Laborde  1.3K             7
# 4  Emmanuel Ameisen   935            11
# 5     Irhum Shafkat    2K            15
#
#                                                 link  \
# 0  https://medium.com/swlh/chatbots-were-the-next...
# 1  https://towardsdatascience.com/python-for-data...
# 2  https://towardsdatascience.com/automated-featu...
# 3  https://medium.freecodecamp.org/machine-learni...
# 4  https://blog.insightdatascience.com/reinforcem...
# 5  https://towardsdatascience.com/intuitively-und...
#
#                                                title  \
# 0  Chatbots were the next big thing: what happene...
# 1  Python for Data Science: 8 Concepts You May Ha...
# 2  Automated Feature Engineering in Python – Towa...
# 3  Machine Learning: how to go from Zero to Hero ...
# 4  Reinforcement Learning from scratch – Insight ...
# 5  Intuitively Understanding Convolutions for Dee...
#
#                                                 text
# 0  Oh, how the headlines blared:\nChatbots were T...
# 1  If you’ve ever found yourself looking up the s...
# 2  Machine learning is increasingly moving from h...
# 3  If your understanding of A.I. and Machine Lear...
# 4  Want to learn about applied Artificial Intelli...
# 5  The advent of powerful and versatile deep lear...

# %% [markdown]
# **Q:** Select just the 'subtitle' and 'date' columns from the DataFrame `df`.

# %% [markdown]
# ###### Conditional selection (==)
# For example, what if we want to filter our articles to show only articles wirtten by Daniel Simmons

# %%
data_f=pd.read_csv('../data/articles.csv')
data_f.author=='Adam Geitgey'# return Series of True/False booleans based on the author of each record
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 332    False
# 333    False
# 334    False
# 335    False
# 336    False
# Name: author, Length: 337, dtype: bool

# %%
#count them
sum(data_f.author=='Adam Geitgey')
# Out:
# 16

# %%
data_f.loc[data_f.author=='Adam Geitgey']
# Out:
#            author  claps  reading_time  \
# 13   Adam Geitgey    35K            15
# 14   Adam Geitgey  14.2K            15
# 15   Adam Geitgey  15.2K            13
# 18   Adam Geitgey  10.4K            15
# 36   Adam Geitgey    35K            15
# 56   Adam Geitgey  14.2K            15
# 57   Adam Geitgey  15.2K            13
# 58   Adam Geitgey  10.4K            15
# 60   Adam Geitgey   6.8K            11
# 61   Adam Geitgey   5.8K            16
# 98   Adam Geitgey  10.4K            15
# 136  Adam Geitgey  10.4K            15
# 138  Adam Geitgey   6.8K            11
# 139  Adam Geitgey   5.8K            16
# 169  Adam Geitgey  14.2K            15
# 170  Adam Geitgey  15.2K            13
#
#                                                   link  \
# 13   https://medium.com/@ageitgey/machine-learning-...
# 14   https://medium.com/@ageitgey/machine-learning-...
# 15   https://medium.com/@ageitgey/machine-learning-...
# 18   https://medium.com/@ageitgey/machine-learning-...
# 36   https://medium.com/@ageitgey/machine-learning-...
# 56   https://medium.com/@ageitgey/machine-learning-...
# 57   https://medium.com/@ageitgey/machine-learning-...
# 58   https://medium.com/@ageitgey/machine-learning-...
# 60   https://medium.com/@ageitgey/machine-learning-...
# 61   https://medium.com/@ageitgey/machine-learning-...
# 98   https://medium.com/@ageitgey/machine-learning-...
# 136  https://medium.com/@ageitgey/machine-learning-...
# 138  https://medium.com/@ageitgey/machine-learning-...
# 139  https://medium.com/@ageitgey/machine-learning-...
# 169  https://medium.com/@ageitgey/machine-learning-...
# 170  https://medium.com/@ageitgey/machine-learning-...
#
#                                                  title  \
# 13    Machine Learning is Fun! – Adam Geitgey – Medium
# 14   Machine Learning is Fun! Part 3: Deep Learning...
# 15   Machine Learning is Fun! Part 4: Modern Face R...
# 18   Machine Learning is Fun! Part 2 – Adam Geitgey...
# 36    Machine Learning is Fun! – Adam Geitgey – Medium
# 56   Machine Learning is Fun! Part 3: Deep Learning...
# 57   Machine Learning is Fun! Part 4: Modern Face R...
# 58   Machine Learning is Fun! Part 2 – Adam Geitgey...
# 60   Machine Learning is Fun Part 6: How to do Spee...
# 61   Machine Learning is Fun Part 5: Language Trans...
# 98   Machine Learning is Fun! Part 2 – Adam Geitgey...
# 136  Machine Learning is Fun! Part 2 – Adam Geitgey...
# 138  Machine Learning is Fun Part 6: How to do Spee...
# 139  Machine Learning is Fun Part 5: Language Trans...
# 169  Machine Learning is Fun! Part 3: Deep Learning...
# 170  Machine Learning is Fun! Part 4: Modern Face R...
#
#                                                   text
# 13   Update: This article is part of a series. Chec...
# 14   Update: This article is part of a series. Chec...
# 15   Update: This article is part of a series. Chec...
# 18   Update: This article is part of a series. Chec...
# 36   Update: This article is part of a series. Chec...
# 56   Update: This article is part of a series. Chec...
# 57   Update: This article is part of a series. Chec...
# 58   Update: This article is part of a series. Chec...
# 60   Update: This article is part of a series. Chec...
# 61   Update: This article is part of a series. Chec...
# 98   Update: This article is part of a series. Chec...
# 136  Update: This article is part of a series. Chec...
# 138  Update: This article is part of a series. Chec...
# 139  Update: This article is part of a series. Chec...
# 169  Update: This article is part of a series. Chec...
# 170  Update: This article is part of a series. Chec...

# %%
data_f.title=='Chatbots were the next big thing: what happened? – The Startup – Medium'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 332    False
# 333    False
# 334    False
# 335    False
# 336    False
# Name: title, Length: 337, dtype: bool

# %%
sum(data_f.title=='Chatbots were the next big thing: what happened? – The Startup – Medium')
# Out:
# 3

# %%
#show them
data_f.loc[data_f.title=='Chatbots were the next big thing: what happened? – The Startup – Medium']
# Out:
#          author claps  reading_time  \
# 0    Justin Lee  8.3K            11
# 86   Justin Lee  8.3K            11
# 273  Justin Lee  8.3K            11
#
#                                                   link  \
# 0    https://medium.com/swlh/chatbots-were-the-next...
# 86   https://medium.com/swlh/chatbots-were-the-next...
# 273  https://medium.com/swlh/chatbots-were-the-next...
#
#                                                  title  \
# 0    Chatbots were the next big thing: what happene...
# 86   Chatbots were the next big thing: what happene...
# 273  Chatbots were the next big thing: what happene...
#
#                                                   text
# 0    Oh, how the headlines blared:\nChatbots were T...
# 86   Oh, how the headlines blared:\nChatbots were T...
# 273  Oh, how the headlines blared:\nChatbots were T...

# %%
(data_f['title']=='Chatbots were the next big thing: what happened? – The Startup – Medium').head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: title, dtype: bool

# %%
data_f.loc[(data_f.claps=='8.3K')&(data_f.reading_time==11)]
# Out:
#          author claps  reading_time  \
# 0    Justin Lee  8.3K            11
# 86   Justin Lee  8.3K            11
# 273  Justin Lee  8.3K            11
#
#                                                   link  \
# 0    https://medium.com/swlh/chatbots-were-the-next...
# 86   https://medium.com/swlh/chatbots-were-the-next...
# 273  https://medium.com/swlh/chatbots-were-the-next...
#
#                                                  title  \
# 0    Chatbots were the next big thing: what happene...
# 86   Chatbots were the next big thing: what happene...
# 273  Chatbots were the next big thing: what happene...
#
#                                                   text
# 0    Oh, how the headlines blared:\nChatbots were T...
# 86   Oh, how the headlines blared:\nChatbots were T...
# 273  Oh, how the headlines blared:\nChatbots were T...

# %%
data_f.loc[data_f.reading_time==11].shape
# Out:
# (27, 6)

# %%
data_f.loc[data_f.reading_time==11]
# Out:
#                       author  claps  reading_time  \
# 0                 Justin Lee   8.3K            11
# 2           William Koehrsen   2.8K            11
# 4           Emmanuel Ameisen    935            11
# 29   Netflix Technology Blog    330            11
# 38                 AirbnbEng    369            11
# 60              Adam Geitgey   6.8K            11
# 77                  James Le  18.4K            11
# 80              David Foster  12.8K            11
# 81               George Seif  11.4K            11
# 86                Justin Lee   8.3K            11
# 88          Emmanuel Ameisen    935            11
# 96             Matt Schlicht     5K            11
# 133              Frank Diana    428            11
# 138             Adam Geitgey   6.8K            11
# 157         Emmanuel Ameisen    935            11
# 177  Netflix Technology Blog     99            11
# 206             David Foster  12.8K            11
# 211             Seth Weidman   2.8K            11
# 212       Gabriel Aldamiz...   5.1K            11
# 218          Kai Stinchcombe    44K            11
# 224          Kai Stinchcombe    44K            11
# 234          Diana Filippova      1            11
# 251              Vivek Yadav    425            11
# 268               Jerry Chen   2.3K            11
# 273               Justin Lee   8.3K            11
# 316      Dhruv Parthasarathy    665            11
# 325             Neelabh Pant     2K            11
#
#                                                   link  \
# 0    https://medium.com/swlh/chatbots-were-the-next...
# 2    https://towardsdatascience.com/automated-featu...
# 4    https://blog.insightdatascience.com/reinforcem...
# 29   https://medium.com/netflix-techblog/system-arc...
# 38   https://medium.com/airbnb-engineering/architec...
# 60   https://medium.com/@ageitgey/machine-learning-...
# 77   https://towardsdatascience.com/a-tour-of-the-t...
# 80   https://medium.com/applied-data-science/how-to...
# 81   https://towardsdatascience.com/the-5-clusterin...
# 86   https://medium.com/swlh/chatbots-were-the-next...
# 88   https://blog.insightdatascience.com/reinforcem...
# 96   https://chatbotsmagazine.com/the-complete-begi...
# 133  https://medium.com/@frankdiana/digital-transfo...
# 138  https://medium.com/@ageitgey/machine-learning-...
# 157  https://blog.insightdatascience.com/reinforcem...
# 177  https://medium.com/netflix-techblog/distribute...
# 206  https://medium.com/applied-data-science/how-to...
# 211  https://hackernoon.com/the-3-tricks-that-made-...
# 212  https://hackernoon.com/how-we-grew-from-0-to-4...
# 218  https://medium.com/@kaistinchcombe/decentraliz...
# 224  https://medium.com/@kaistinchcombe/decentraliz...
# 234  https://medium.com/@dnafilippova/de-la-coop%C3...
# 251  https://chatbotslife.com/using-augmentation-to...
# 268  https://news.greylock.com/the-new-moats-53f61a...
# 273  https://medium.com/swlh/chatbots-were-the-next...
# 316  https://medium.com/@dhruvp/how-to-write-a-neur...
# 325  https://blog.statsbot.co/time-series-predictio...
#
#                                                  title  \
# 0    Chatbots were the next big thing: what happene...
# 2    Automated Feature Engineering in Python – Towa...
# 4    Reinforcement Learning from scratch – Insight ...
# 29   System Architectures for Personalization and R...
# 38   Architecting a Machine Learning System for Ris...
# 60   Machine Learning is Fun Part 6: How to do Spee...
# 77   A Tour of The Top 10 Algorithms for Machine Le...
# 80   How to build your own AlphaZero AI using Pytho...
# 81   The 5 Clustering Algorithms Data Scientists Ne...
# 86   Chatbots were the next big thing: what happene...
# 88   Reinforcement Learning from scratch – Insight ...
# 96   The Complete Beginner’s Guide To Chatbots – Ch...
# 133  Digital Transformation of Business and Society...
# 138  Machine Learning is Fun Part 6: How to do Spee...
# 157  Reinforcement Learning from scratch – Insight ...
# 177  Distributed Neural Networks with GPUs in the A...
# 206  How to build your own AlphaZero AI using Pytho...
# 211  The 3 Tricks That Made AlphaGo Zero Work – Hac...
# 212  How we grew from 0 to 4 million women on our f...
# 218  Blockchain is not only crappy technology but a...
# 224  Blockchain is not only crappy technology but a...
# 234  De la coopération entre les hommes et les mac...
# 251  An augmentation based deep neural network appr...
# 268              The New Moats – Greylock Perspectives
# 273  Chatbots were the next big thing: what happene...
# 316  Write an AI to win at Pong from scratch with R...
# 325  A Guide For Time Series Prediction Using Recur...
#
#                                                   text
# 0    Oh, how the headlines blared:\nChatbots were T...
# 2    Machine learning is increasingly moving from h...
# 4    Want to learn about applied Artificial Intelli...
# 29   by Xavier Amatriain and Justin Basilico\nIn ou...
# 38   By Naseem Hakim & Aaron Keys\nAt Airbnb, we wa...
# 60   Update: This article is part of a series. Chec...
# 77   In machine learning, there’s something called ...
# 80   In this article I’ll attempt to cover three th...
# 81   Clustering is a Machine Learning technique tha...
# 86   Oh, how the headlines blared:\nChatbots were T...
# 88   Want to learn about applied Artificial Intelli...
# 96   What are chatbots? Why are they such a big opp...
# 133  At a recent KPMG Robotic Innovations event, Fu...
# 138  Update: This article is part of a series. Chec...
# 157  Want to learn about applied Artificial Intelli...
# 177  by Alex Chen, Justin Basilico, and Xavier Amat...
# 206  In this article I’ll attempt to cover three th...
# 211  There were many advances in Deep Learning and ...
# 212  Three years ago we launched Chicisimo, our goa...
# 218  Blockchain is not only crappy technology but a...
# 224  Blockchain is not only crappy technology but a...
# 234  Originally published at www.cuberevue.com on N...
# 251  Overview\nIn this post, we will go over the wo...
# 268  To build a sustainable and profitable business...
# 273  Oh, how the headlines blared:\nChatbots were T...
# 316  There’s a huge difference between reading abou...
# 325  The Statsbot team has already published the ar...

# %%
data_f.loc[data_f.claps=='8.3K'].shape
# Out:
# (3, 6)

# %% [markdown]
# ###### Built-in conditional selectors

# %%
# use isin() 
data_f.loc[data_f.reading_time.isin([5,11,12])]
# Out:
#                       author claps  reading_time  \
# 0                 Justin Lee  8.3K            11
# 2           William Koehrsen  2.8K            11
# 4           Emmanuel Ameisen   935            11
# 17               Gil Fewster  3.3K             5
# 29   Netflix Technology Blog   330            11
# ..                       ...   ...           ...
# 298               Datafiniti     3             5
# 316      Dhruv Parthasarathy   665            11
# 317           Waleed Abdulla   507            12
# 324                nafrondel  1.7K             5
# 325             Neelabh Pant    2K            11
#
#                                                   link  \
# 0    https://medium.com/swlh/chatbots-were-the-next...
# 2    https://towardsdatascience.com/automated-featu...
# 4    https://blog.insightdatascience.com/reinforcem...
# 17   https://medium.freecodecamp.org/the-mind-blowi...
# 29   https://medium.com/netflix-techblog/system-arc...
# ..                                                 ...
# 298  https://blog.datafiniti.co/classifying-website...
# 316  https://medium.com/@dhruvp/how-to-write-a-neur...
# 317  https://medium.com/@waleedka/traffic-sign-reco...
# 324  https://medium.com/@nafrondel/you-requested-so...
# 325  https://blog.statsbot.co/time-series-predictio...
#
#                                                  title  \
# 0    Chatbots were the next big thing: what happene...
# 2    Automated Feature Engineering in Python – Towa...
# 4    Reinforcement Learning from scratch – Insight ...
# 17   The mind-blowing AI announcement from Google t...
# 29   System Architectures for Personalization and R...
# ..                                                 ...
# 298  Classifying Websites with Neural Networks – Kn...
# 316  Write an AI to win at Pong from scratch with R...
# 317  Traffic Sign Recognition with TensorFlow – Wal...
# 324  You requested someone with a degree in this? *...
# 325  A Guide For Time Series Prediction Using Recur...
#
#                                                   text
# 0    Oh, how the headlines blared:\nChatbots were T...
# 2    Machine learning is increasingly moving from h...
# 4    Want to learn about applied Artificial Intelli...
# 17   Disclaimer: I’m not an expert in neural networ...
# 29   by Xavier Amatriain and Justin Basilico\nIn ou...
# ..                                                 ...
# 298  At Datafiniti, we have a strong need for conve...
# 316  There’s a huge difference between reading abou...
# 317  This is part 1 of a series about building a de...
# 324  You requested someone with a degree in this? *...
# 325  The Statsbot team has already published the ar...
#
# [68 rows x 6 columns]

# %% [markdown]
# ###### Filtering data using query() method
# taking expression to filter data, return Filtered Data

# %%
data_f.query('reading_time < 5') # return articles have reading time greater than 5
# Out:
#                               author  claps  reading_time  \
# 10                  Sophia Arakelyan      7             4
# 21                        Eran Kampf     57             3
# 23                         Xu Wenhao      1             4
# 34                      Akash Shende      1             3
# 35             Hrishikesh Huilgolkar      1             4
# 41                   Nikhil Dandekar    116             3
# 49                        Matt Fogel    938             4
# 50                  Illia Polosukhin    255             3
# 51                     Ahmed El Deeb    283             3
# 52            Christophe Bourguignat    157             4
# 53               I'Boss Potiwarakorn    128             3
# 54                             samim    301             4
# 95                  Sophia Arakelyan      7             4
# 102                        Greg Fish      1             4
# 104                        Greg Fish      1             4
# 109                        Greg Fish      1             4
# 110                        Greg Fish      2             3
# 113                             Theo      3             4
# 114                             x.ai      1             2
# 120                     Joe Johnston     38             4
# 122                      Pandorabots     14             3
# 123                Denny Vrandečić      4             4
# 131              Milo Spencer-Harper   2.2K             3
# 164               Abhishek Parbhakar   1.7K             3
# 167  Erick Muzart Fonseca dos Santos     16             2
# 178               Francesco Gadaleta      3             4
# 179              Milo Spencer-Harper   2.2K             3
# 180                      Jim Fleming    294             3
# 181              Milo Spencer-Harper   1.8K             4
# 184                 Illia Polosukhin    108             3
# 187                      Jim Fleming    165             4
# 210                          Bargava  11.8K             3
# 219                    savedroid ICO    340             3
# 233                             Theo      3             4
# 239                       Matt Wiese      4             3
# 242                     James Cooper     57             3
# 245                        iDanScott      3             4
# 281                    Amine Aoullay     58             4
# 287                          Wallarm     72             4
# 289                    Amine Aoullay     58             4
# 300              Milo Spencer-Harper   2.2K             3
# 304              Milo Spencer-Harper     42             3
# 306                   Dr Ben Medlock     32             4
# 330             Oleksandr Savsunenko   5.5K             4
# 334                       Devin Soni   5.8K             4
#
#                                                   link  \
# 10   https://buzzrobot.com/from-ballerina-to-ai-res...
# 21   https://developerzen.com/data-mining-handling-...
# 23   https://xuwenhao.com/%E5%BB%BA%E8%AE%AE%E7%9A%...
# 34   https://medium.com/@akash0x53/color-based-obje...
# 35   https://medium.com/@hrishikeshio/traveling-san...
# 41   https://towardsdatascience.com/what-makes-a-go...
# 49   https://medium.com/swlh/the-7-best-data-scienc...
# 50   https://medium.com/@ilblackdragon/tensorflow-t...
# 51   https://medium.com/rants-on-machine-learning/t...
# 52   https://medium.com/@chris_bour/6-tricks-i-lear...
# 53   https://medium.com/o-v-e-r-f-i-t-t-e-d/machine...
# 54   https://medium.com/@samim/generating-stories-a...
# 95   https://buzzrobot.com/from-ballerina-to-ai-res...
# 102  https://worldofweirdthings.com/looking-for-a-g...
# 104  https://worldofweirdthings.com/the-technical-t...
# 109  https://worldofweirdthings.com/why-you-just-ca...
# 110  https://worldofweirdthings.com/why-do-we-want-...
# 113  https://becominghuman.ai/is-there-a-future-for...
# 114  https://medium.com/@xdotai/i-scheduled-1-019-m...
# 120  https://medium.com/universal-mind/how-i-tracke...
# 122  https://medium.com/pandorabots-blog/using-oob-...
# 123  https://medium.com/@vrandezo/ai-is-coming-and-...
# 131  https://medium.com/technology-invention-and-mo...
# 164  https://towardsdatascience.com/why-data-scient...
# 167  https://medium.com/deeplearningbrasilia/o-grup...
# 178  https://hackernoon.com/gradient-descent-vs-coo...
# 179  https://medium.com/technology-invention-and-mo...
# 180  https://medium.com/jim-fleming/loading-a-tenso...
# 181  https://medium.com/deep-learning-101/how-to-ge...
# 184  https://medium.com/@ilblackdragon/tensorflow-t...
# 187  https://medium.com/jim-fleming/highway-network...
# 210  https://towardsdatascience.com/how-to-learn-de...
# 219  https://medium.com/@ico_8796/sneakpeek-the-sav...
# 233  https://becominghuman.ai/is-there-a-future-for...
# 239  https://medium.com/@mattwiese/digital-companio...
# 242  https://render.betaworks.com/announcing-poncho...
# 245  https://medium.com/@iDanScott/the-bejeweled-so...
# 281  https://towardsdatascience.com/how-to-use-nois...
# 287  https://lab.wallarm.com/tensorflow-dataset-api...
# 289  https://towardsdatascience.com/how-to-use-nois...
# 300  https://medium.com/technology-invention-and-mo...
# 304  https://medium.com/@miloharper/thanks-so-much-...
# 306  https://medium.com/@Ben_Medlock/why-turing-s-l...
# 330  https://hackernoon.com/the-new-neural-internet...
# 334  https://towardsdatascience.com/spiking-neural-...
#
#                                                  title  \
# 10   From Ballerina to AI Researcher: Part I – buZZ...
# 21   Data Mining — Handling Missing Values the Data...
# 23                            建议的程序员学习LDA算法的步骤 – 蒸汽与魔法
# 34   Color Based Object Segmentation – Akash Shende...
# 35   Traveling santa Problem — An incompetent algor...
# 41   What makes a good data scientist/engineer? – T...
# 49   The 7 Best Data Science and Machine Learning P...
# 50   TensorFlow Tutorial— Part 1 – Illia Polosukhin...
# 51   The Unreasonable Effectiveness of Random Fores...
# 52   6 Tricks I Learned From The OTTO Kaggle Challe...
# 53   Machine Learning เรียนอะไร, รู้ไปทําไม – O v e...
# 54    Generating Stories about Images – samim – Medium
# 95   From Ballerina to AI Researcher: Part I – buZZ...
# 102  looking for a ghost in the machine – [ weird t...
# 104  the technical trouble with humanoid robots – [...
# 109  why you just can’t black box an a.i. – [ weird...
# 110  why do we want to build a fully fledged a.g.i....
# 113  Is there a future for innovation ? – Becoming ...
# 114  I scheduled 1,019 meetings in 2012 — and that ...
# 120  How I tracked my house movements using iBeacon...
# 122  Using OOB Tags in AIML: Part I – pandorabots-b...
# 123  AI is coming, and it will be boring – Denny Vr...
# 131  How to build a multi-layered neural network in...
# 164  Why Data Scientists love Gaussian? – Towards D...
# 167  O Grupo de Estudo em Deep Learning de Brasíli...
# 178  Gradient descent vs coordinate descent – Hacke...
# 179  How to build a multi-layered neural network in...
# 180  Loading a TensorFlow graph with the C++ API – ...
# 181  Video of a neural network learning – Deep Lear...
# 184  Tensorflow Tutorial — Part 2 – Illia Polosukhi...
# 187  Highway Networks with TensorFlow – Jim Fleming...
# 210  How to learn Deep Learning in 6 months – Towar...
# 219  #SNEAKPEEK The savedroid crypto saving app — P...
# 233  Is there a future for innovation ? – Becoming ...
# 239        Digital Companionship – Matt Wiese – Medium
# 242  Announcing Poncho the WeatherBot – Render-from...
# 245      C# Plays Bejeweled Blitz – iDanScott – Medium
# 281  How to use Noise to your advantage ? – Towards...
# 287  TensorFlow Dataset API for increasing training...
# 289  How to use Noise to your advantage ? – Towards...
# 300  How to build a multi-layered neural network in...
# 304  Thanks so much for your response Jared. Really...
# 306  Why Turing’s legacy demands a smarter keyboard...
# 330    The New Neural Internet is Coming – Hacker Noon
# 334  Spiking Neural Networks, the Next Generation o...
#
#                                                   text
# 10   Last year, I published the article “From Balle...
# 21   I’ve recently answered Predicting missing data...
# 23   这一阵为了工作上的关系,花了点时间学习了一下LDA算法,说实话,对于我这个学CS而非学数学的...
# 34   In this picture, Pranav Mistry is using color ...
# 35   Kaggle announced the Traveling santa problem i...
# 41   The term data scientist has been used lately t...
# 49   Data science and machine learning have long be...
# 50   UPD (April 20, 2016): Scikit Flow has been mer...
# 51   It’s very common for machine learning practiti...
# 52   Here are a few things I learned from the OTTO ...
# 53   Machine Learning จริงๆแล้วมันคืออะไรกันแน่? คร...
# 54   Stories are a fundamental human tool that we u...
# 95   Last year, I published the article “From Balle...
# 102  A short while ago, I wrote about some of the c...
# 104  If you’ve been reading this blog long enough, ...
# 109  Singularitarians generally believe two things ...
# 110  Undoubtedly the most ambitious idea in the wor...
# 113  Have you noticed how tech savvy children have ...
# 114  The number of meetings that I scheduled in 201...
# 120  Recently I’ve started experimenting more and m...
# 122  Suppose you are building an Intelligent Virtua...
# 123  I was asked about my opinion on this topic, an...
# 131  In my last blog post, thanks to an excellent b...
# 164  For Deep Learning & Machine Learning engineers...
# 167  O Grupo de Estudo em Deep Learning de Brasíli...
# 178  When it comes to function minimization, it’s t...
# 179  In my last blog post, thanks to an excellent b...
# 180  Check out the related post: Loading TensorFlow...
# 181  As part of my quest to learn about AI, I gener...
# 184  In the previous Part 1 of this tutorial, I int...
# 187  This week I implemented highway networks to ge...
# 210  It is quite possible to learn, follow and cont...
# 219  The international beta of our brand new crypto...
# 233  Have you noticed how tech savvy children have ...
# 239  Recently, I chose to treat myself to a movie I...
# 242  You can now get personal weather forecasts in ...
# 245  As some of you reading this may or may not alr...
# 281  For scientists, random fluctuations, or noise ...
# 287  Wallarm AI engine is the heart of our security...
# 289  For scientists, random fluctuations, or noise ...
# 300  In my last blog post, thanks to an excellent b...
# 304  Thanks so much for your response Jared. Really...
# 306  Why Turing’s legacy demands a smarter keyboard...
# 330  How it all began / The Landscape\nThink of the...
# 334  Everyone who has been remotely tuned in to rec...

# %% [markdown]
# **Q:** in data ('medium_data.csv')
# - count of only the articles where the number of claps is greater than 1000.
# - Select only the articles that it is publicated by Towards Data Science where the number of claps is greater than 1000.

# %% [markdown]
# ###### Assigning data

# %%
len(data_f)
# Out:
# 337

# %%
# add column
import numpy as np
data_f['num_comments']=np.random.randint(1,50,len(data_f))
data_f.head()
# Out:
#              author claps  reading_time  \
# 0        Justin Lee  8.3K            11
# 1       Conor Dewey  1.4K             7
# 2  William Koehrsen  2.8K            11
# 3      Gant Laborde  1.3K             7
# 4  Emmanuel Ameisen   935            11
#
#                                                 link  \
# 0  https://medium.com/swlh/chatbots-were-the-next...
# 1  https://towardsdatascience.com/python-for-data...
# 2  https://towardsdatascience.com/automated-featu...
# 3  https://medium.freecodecamp.org/machine-learni...
# 4  https://blog.insightdatascience.com/reinforcem...
#
#                                                title  \
# 0  Chatbots were the next big thing: what happene...
# 1  Python for Data Science: 8 Concepts You May Ha...
# 2  Automated Feature Engineering in Python – Towa...
# 3  Machine Learning: how to go from Zero to Hero ...
# 4  Reinforcement Learning from scratch – Insight ...
#
#                                                 text  num_comments
# 0  Oh, how the headlines blared:\nChatbots were T...            35
# 1  If you’ve ever found yourself looking up the s...            44
# 2  Machine learning is increasingly moving from h...            40
# 3  If your understanding of A.I. and Machine Lear...             1
# 4  Want to learn about applied Artificial Intelli...            45

# %%
len(data_f)
# Out:
# 337

# %% [markdown]
# **Q:** change value of column `id`  into numbers that has mean = 0.0 in data ('medium_data.csv').

# %% [markdown]
# ###### Drop specified labels from rows or columns.

# %%
# we can remove rows or columns from data by drop()
data_f.drop(['num_comments'], axis=1,inplace=True)
data_f.head()
# Out:
#              author claps  reading_time  \
# 0        Justin Lee  8.3K            11
# 1       Conor Dewey  1.4K             7
# 2  William Koehrsen  2.8K            11
# 3      Gant Laborde  1.3K             7
# 4  Emmanuel Ameisen   935            11
#
#                                                 link  \
# 0  https://medium.com/swlh/chatbots-were-the-next...
# 1  https://towardsdatascience.com/python-for-data...
# 2  https://towardsdatascience.com/automated-featu...
# 3  https://medium.freecodecamp.org/machine-learni...
# 4  https://blog.insightdatascience.com/reinforcem...
#
#                                                title  \
# 0  Chatbots were the next big thing: what happene...
# 1  Python for Data Science: 8 Concepts You May Ha...
# 2  Automated Feature Engineering in Python – Towa...
# 3  Machine Learning: how to go from Zero to Hero ...
# 4  Reinforcement Learning from scratch – Insight ...
#
#                                                 text
# 0  Oh, how the headlines blared:\nChatbots were T...
# 1  If you’ve ever found yourself looking up the s...
# 2  Machine learning is increasingly moving from h...
# 3  If your understanding of A.I. and Machine Lear...
# 4  Want to learn about applied Artificial Intelli...

# %% [markdown]
# ##### Maps
# It is possible to iterate over a DataFrame or Series as you would with a list, but doing so — especially on large datasets — is very slow.
#
# map is function that takes one set of values and "maps" them to another set of values.
# We can transform data from the format it is in now to the format that we want it using Maps.
#
#
# - `apply` method can be applied both to series and dataframes,if we want to transform a whole DataFrame by calling a custom method on each row.
#
# ###### NOTE:
#  `apply` don't modify the original data they're called on

# %%
def str_to_float(strk):
    return float(strk[:-1]) if 'K'in strk else float(strk)/1000.0
    
str_to_float('599')
# Out:
# 0.599

# %%
data_f.loc[:,'claps'].head()
# Out:
# 0    8.3K
# 1    1.4K
# 2    2.8K
# 3    1.3K
# 4     935
# Name: claps, dtype: object

# %%
data_f.loc[:,'claps'].apply(str_to_float)
# Out:
# 0      8.300
# 1      1.400
# 2      2.800
# 3      1.300
# 4      0.935
#        ...
# 332    3.400
# 333    2.800
# 334    5.800
# 335    3.900
# 336    2.400
# Name: claps, Length: 337, dtype: float64

# %%
def str_to_float2(row):
    return float(row.claps[:-1]) if 'K'in row.claps else float(row.claps)/1000.0


data_f.apply(str_to_float2, axis=1)
# Out:
# 0      8.300
# 1      1.400
# 2      2.800
# 3      1.300
# 4      0.935
#        ...
# 332    3.400
# 333    2.800
# 334    5.800
# 335    3.900
# 336    2.400
# Length: 337, dtype: float64

# %% [markdown]
# #### Grouping
# `groupby()` function is used to split the data into groups based on some criteria.

# %%
data_f.head(3)
# Out:
#              author claps  reading_time  \
# 0        Justin Lee  8.3K            11
# 1       Conor Dewey  1.4K             7
# 2  William Koehrsen  2.8K            11
#
#                                                 link  \
# 0  https://medium.com/swlh/chatbots-were-the-next...
# 1  https://towardsdatascience.com/python-for-data...
# 2  https://towardsdatascience.com/automated-featu...
#
#                                                title  \
# 0  Chatbots were the next big thing: what happene...
# 1  Python for Data Science: 8 Concepts You May Ha...
# 2  Automated Feature Engineering in Python – Towa...
#
#                                                 text
# 0  Oh, how the headlines blared:\nChatbots were T...
# 1  If you’ve ever found yourself looking up the s...
# 2  Machine learning is increasingly moving from h...

# %%
data_f.loc[data_f.author=='Abhishek Parbhakar']
# Out:
#                  author claps  reading_time  \
# 8    Abhishek Parbhakar   937             6
# 92   Abhishek Parbhakar   937             6
# 159  Abhishek Parbhakar   937             6
# 164  Abhishek Parbhakar  1.7K             3
#
#                                                   link  \
# 8    https://towardsdatascience.com/must-know-infor...
# 92   https://towardsdatascience.com/must-know-infor...
# 159  https://towardsdatascience.com/must-know-infor...
# 164  https://towardsdatascience.com/why-data-scient...
#
#                                                  title  \
# 8    Must know Information Theory concepts in Deep ...
# 92   Must know Information Theory concepts in Deep ...
# 159  Must know Information Theory concepts in Deep ...
# 164  Why Data Scientists love Gaussian? – Towards D...
#
#                                                   text
# 8    Information theory is an important field that ...
# 92   Information theory is an important field that ...
# 159  Information theory is an important field that ...
# 164  For Deep Learning & Machine Learning engineers...

# %%
sdata=data_f.groupby('author').sum() #sum values of reading_time for each author

# %%
sdata
# Out:
#                     reading_time
# author
# Abhishek Parbhakar            21
# Adam Geitgey                 228
# Ahmed El Deeb                 10
# AirbnbEng                     20
# Akash Shende                   3
# ...                          ...
# nafrondel                      5
# paulson                       17
# samim                         12
# savedroid ICO                  3
# x.ai                           2
#
# [182 rows x 1 columns]

# %%
sdata.sort_values('reading_time',ascending=False)
# Out:
#                                  reading_time
# author
# Adam Geitgey                              228
# Slav Ivanov                               133
# David Venturi                              80
# Dhruv Parthasarathy                        71
# Tim Anglade                                69
# ...                                       ...
# Matt Wiese                                  3
# Nikhil Dandekar                             3
# Pandorabots                                 3
# Erick Muzart Fonseca dos Santos             2
# x.ai                                        2
#
# [182 rows x 1 columns]

# %%
data_f.index
# Out:
# RangeIndex(start=0, stop=337, step=1)

# %% [markdown]
# ###### Q: Get the least reading time in each title articles category in data ('medium_data.csv').

# %% [markdown]
# ###### Combining:
# we use `concat()` to combine two dataframe and Given a list of dataframe .

# %%
data_f2=pd.read_csv('../data/medium_data.csv',nrows=100)# set The same number of rows of data_f ===> data_f.shape[0]

# %%
article_data=pd.concat([data_f, data_f2])
article_data.head()
# Out:
#              author claps  reading_time  \
# 0        Justin Lee  8.3K            11
# 1       Conor Dewey  1.4K             7
# 2  William Koehrsen  2.8K            11
# 3      Gant Laborde  1.3K             7
# 4  Emmanuel Ameisen   935            11
#
#                                                 link  \
# 0  https://medium.com/swlh/chatbots-were-the-next...
# 1  https://towardsdatascience.com/python-for-data...
# 2  https://towardsdatascience.com/automated-featu...
# 3  https://medium.freecodecamp.org/machine-learni...
# 4  https://blog.insightdatascience.com/reinforcem...
#
#                                                title  \
# 0  Chatbots were the next big thing: what happene...
# 1  Python for Data Science: 8 Concepts You May Ha...
# 2  Automated Feature Engineering in Python – Towa...
# 3  Machine Learning: how to go from Zero to Hero ...
# 4  Reinforcement Learning from scratch – Insight ...
#
#                                                 text  id  url subtitle image  \
# 0  Oh, how the headlines blared:\nChatbots were T... NaN  NaN      NaN   NaN
# 1  If you’ve ever found yourself looking up the s... NaN  NaN      NaN   NaN
# 2  Machine learning is increasingly moving from h... NaN  NaN      NaN   NaN
# 3  If your understanding of A.I. and Machine Lear... NaN  NaN      NaN   NaN
# 4  Want to learn about applied Artificial Intelli... NaN  NaN      NaN   NaN
#
#    responses publication date
# 0        NaN         NaN  NaN
# 1        NaN         NaN  NaN
# 2        NaN         NaN  NaN
# 3        NaN         NaN  NaN
# 4        NaN         NaN  NaN

# %% [markdown]
# ###### Dealing with Missing Data
# Entries missing values are given the value NaN.
#
# To select NaN entries we can use `isnull()` .
#
# To remove all columns or rows that contain least one missing value we can use `dropna()` .
#
# To fill in missing values in a dataframe OR specify what we want the NaN values to be replaced with we can use `fillna()` .

# %%
article_data.isnull().sum()
# Out:
# author          100
# claps             0
# reading_time      0
# link            100
# title             0
# text            100
# id              337
# url             337
# subtitle        385
# image           339
# responses       337
# publication     337
# date            337
# dtype: int64

# %%
#article_data.dropna() #remove all the rows that contain a missing value
article_data.dropna(axis=1) #remove all columns with at least one missing value
# Out:
#    claps  reading_time                                              title
# 0   8.3K            11  Chatbots were the next big thing: what happene...
# 1   1.4K             7  Python for Data Science: 8 Concepts You May Ha...
# 2   2.8K            11  Automated Feature Engineering in Python – Towa...
# 3   1.3K             7  Machine Learning: how to go from Zero to Hero ...
# 4    935            11  Reinforcement Learning from scratch – Insight ...
# ..   ...           ...                                                ...
# 95     7             6  How to Live in the Present and Make Your Time ...
# 96    77             7                                 Look ma, no hands!
# 97    37             6    Raised on Nintendo 64: My Story on Bilingualism
# 98   111             4              I Don’t Know What To Do With My Hands
# 99    64             7  3 Tips for Sticking to New Habits When Travelling
#
# [437 rows x 3 columns]

# %%
article_data.loc[:,['id','url','responses','publication','date']].fillna("Unknown")
# Out:
#          id                                                url responses  \
# 0   Unknown                                            Unknown   Unknown
# 1   Unknown                                            Unknown   Unknown
# 2   Unknown                                            Unknown   Unknown
# 3   Unknown                                            Unknown   Unknown
# 4   Unknown                                            Unknown   Unknown
# ..      ...                                                ...       ...
# 95     96.0  https://medium.com/swlh/how-to-live-in-the-pre...       0.0
# 96     97.0  https://medium.com/swlh/look-ma-no-hands-3ddef...       0.0
# 97     98.0  https://medium.com/swlh/raised-on-nintendo-64-...       3.0
# 98     99.0  https://medium.com/swlh/i-dont-know-what-to-do...       0.0
# 99    100.0  https://medium.com/swlh/3-tips-for-sticking-to...       0.0
#
#     publication        date
# 0       Unknown     Unknown
# 1       Unknown     Unknown
# 2       Unknown     Unknown
# 3       Unknown     Unknown
# 4       Unknown     Unknown
# ..          ...         ...
# 95  The Startup  2019-05-30
# 96  The Startup  2019-05-30
# 97  The Startup  2019-05-30
# 98  The Startup  2019-05-30
# 99  The Startup  2019-05-30
#
# [437 rows x 5 columns]

# %% [markdown]
# **Q:** Replace Missing Data in `subtitle` by text='no subtitle'  in data ('medium_data.csv').
